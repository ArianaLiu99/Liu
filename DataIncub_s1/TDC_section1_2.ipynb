# %%
#Time long-day

plt.figure(figsize=(10,6), dpi= 80)
sns.distplot(timelong_fp_d, hist=False, kde=True, rug=True,  kde_kws={"color":"blue", "lw":1.5, 'linestyle':'--'}, rug_kws={'color':'deepskyblue','alpha':1, 'lw':2,}, label='first interaction to purchase')
sns.distplot(timelong_lp_d, hist=False, kde=True, rug=True, kde_kws={"color":"lightseagreen", "lw":1.5, 'linestyle':'--'}, rug_kws={'color':'lightseagreen', 'alpha':0.5, 'lw':2, 'height':0.1}, label='last interaction to purchase')
sns.distplot(timelong_fl_d, hist=False, kde=True, rug=True, kde_kws={"color":"lightcoral", "lw":1.5, 'linestyle':'--'}, rug_kws={'color':'pink', 'alpha':0.1, 'lw':2, 'height':0.1}, label='first to last interaction')

plt.axvline(avg_fp_d, color='blue', linestyle=":", alpha=2)
#plt.text(avg_fp_d+2,0.012, 'Average (first-purchase): %.1fdays' %(avg_fp_d), color = 'indianred')
plt.axvline(avg_lp_d, color='lightseagreen', linestyle=":", alpha=2)
#plt.text(avg_lp_d+2,0.022, 'Average (last-purchase): %.1fdays' %(avg_lp_d), color = 'darkcyan')
plt.axvline(avg_fl_d, color='lightcoral', linestyle=":", alpha=0.5)
#plt.text(avg_fl_d+2,0.022, 'Average (first-last): %.1fdays' %(avg_fl_d), color = 'blue')

#plt.ylim([0,0.05])
plt.grid(linestyle='--')
plt.title('Time Long a Customer Spent (day)', fontsize=22)
plt.xlabel('days',fontsize=15)
plt.ylabel('Prop',fontsize=15)
plt.legend()
plt.show()
